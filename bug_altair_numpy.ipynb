# %%
# %matplotlib inline 
#%matplotlib notebook
# %reload_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
from altair import Chart
from IPython import display

df = pd.DataFrame([dict(
        x=1,
        y=2,
        )])

Chart(df).encode(x='x', y='y')
# Out:
# <div class="vega-embed" id="6010f919-5e3c-4bcb-bf25-08eaad149247"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %%
import seaborn as sns

df_numpy = pd.DataFrame([dict(
        x=np.array(1),
        y=np.array(2),
        )])

sns.pairplot(df_numpy)

# %%
Chart(df_numpy).encode(x='x', y='y')
# Out:
# <div class="vega-embed" id="d338b6d0-8e00-47f6-b702-859eeefef94c"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /net/ssd/software/anaconda/envs/py35/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     907             method = _safe_get_formatter_method(obj, self.print_method)
#     908             if method is not None:
# --> 909                 method()
#     910                 return True
#     911
#
# /home/boeddeker/.local/lib/python3.5/site-packages/vega/base.py in _ipython_display_(self)
#      48         )
#      49         publish_display_data(
# ---> 50             {'application/javascript': self._generate_js(id)},
#      51             metadata={'jupyter-vega': '#{0}'.format(id)}
#      52         )
#
# /home/boeddeker/.local/lib/python3.5/site-packages/vega/base.py in _generate_js(self, id, **kwds)
#      35         payload = template.format(
#      36             selector=selector,
# ---> 37             spec=json.dumps(self.spec, **kwds),
#      38             type=self.render_type
#      39         )
#
# /net/ssd/software/anaconda/envs/py35/lib/python3.5/json/__init__.py in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     228         cls is None and indent is None and separators is None and
#     229         default is None and not sort_keys and not kw):
# --> 230         return _default_encoder.encode(obj)
#     231     if cls is None:
#     232         cls = JSONEncoder
#
# /net/ssd/software/anaconda/envs/py35/lib/python3.5/json/encoder.py in encode(self, o)
#     196         # exceptions aren't as detailed.  The list call should be roughly
#     197         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 198         chunks = self.iterencode(o, _one_shot=True)
#     199         if not isinstance(chunks, (list, tuple)):
#     200             chunks = list(chunks)
#
# /net/ssd/software/anaconda/envs/py35/lib/python3.5/json/encoder.py in iterencode(self, o, _one_shot)
#     254                 self.key_separator, self.item_separator, self.sort_keys,
#     255                 self.skipkeys, _one_shot)
# --> 256         return _iterencode(o, 0)
#     257
#     258 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# /net/ssd/software/anaconda/envs/py35/lib/python3.5/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(repr(o) + " is not JSON serializable")
#     180
#     181     def encode(self, o):
#
# TypeError: array(1) is not JSON serializable
